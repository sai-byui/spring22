# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
db = pd.read_csv("/content/drive/MyDrive/EarthQuake/eqint_tsqp.csv")

# %%
db.describe()
# Out:
#                 YEAR          MONTH            DAY           HOUR  \
# count  157015.000000  156999.000000  156978.000000  156262.000000
# mean     1957.648900       6.648342      15.655327      11.133980
# std        21.640806       3.444969       8.916499       6.825628
# min      1638.000000       1.000000       1.000000       0.000000
# 25%      1945.000000       4.000000       8.000000       5.000000
# 50%      1961.000000       7.000000      16.000000      11.000000
# 75%      1975.000000      10.000000      23.000000      17.000000
# max      1985.000000      12.000000      31.000000      23.000000
#
#               MINUTE         SECOND   LOCAL_TO_UTC       LATITUDE  \
# count  156132.000000  124069.000000  150549.000000  142083.000000
# mean       29.030109      28.987162       7.430059      38.738542
# std        17.454231      17.043556       1.346179       6.997466
# min         0.000000       0.000000       4.000000       4.600000
# ...

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157015 entries, 0 to 157014
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   YEAR                  157015 non-null  int64
#  1   MONTH                 156999 non-null  float64
#  2   DAY                   156978 non-null  float64
#  3   HOUR                  156262 non-null  float64
#  4   MINUTE                156132 non-null  float64
#  5   SECOND                124069 non-null  float64
#  6   LOCAL_TO_UTC          150549 non-null  float64
#  7   UNPUB_OR_GROUPED_INT  20970 non-null   object
#  8   LATITUDE              142083 non-null  float64
#  9   LONGITUDE             142083 non-null  float64
#  10  MAGNITUDE             110184 non-null  float64
#  11  EQ_DEPTH              57406 non-null   float64
#  12  EPIDIST               140662 non-null  float64
#  13  CITY_LAT              155455 non-null  float64
# ...

# %%
db.head()
# Out:
#    YEAR  MONTH   DAY  HOUR  MINUTE  SECOND  LOCAL_TO_UTC UNPUB_OR_GROUPED_INT  \
# 0  1852   11.0  27.0   NaN     NaN     NaN           8.0                  NaN
# 1  1852   11.0  27.0   NaN     NaN     NaN           8.0                  NaN
# 2  1852   11.0  27.0   NaN     NaN     NaN           8.0                  NaN
# 3  1852   11.0  27.0   NaN     NaN     NaN           8.0                  NaN
# 4  1860   11.0  12.0   NaN     NaN     NaN           8.0                  NaN
#
#    LATITUDE  LONGITUDE  MAGNITUDE  EQ_DEPTH  EPIDIST  CITY_LAT  CITY_LON  MMI  \
# 0      34.5     -119.0        NaN       NaN      0.0     34.50   -119.00  7.0
# 1      34.5     -119.0        NaN       NaN    258.0     33.02   -116.84  6.0
# 2      34.5     -119.0        NaN       NaN    159.0     35.35   -120.41  6.0
# 3      34.5     -119.0        NaN       NaN      NaN       NaN       NaN  6.0
# 4      41.0     -124.0        NaN       NaN     32.0     40.76   -124.22  8.0
#
# ...

# %%
db.shape
# Out:
# (157015, 20)

# %%
db.plot.hist()
